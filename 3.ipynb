# %% [markdown]
# # Module 3: Clone, Modify, Deploy
#
# Clone an existing environment, modify it, test locally, and deploy to HF Spaces.
#
# **Time:** ~25 min · **Difficulty:** Intermediate · **GPU:** Not required
#
# > **Note:** The deployment steps (`openenv push`) require a Hugging Face account and token. The local testing steps work without one.

# %%
# Install dependencies
# !uv pip install -q openenv-core==0.2.2 "git+https://github.com/meta-pytorch/OpenEnv.git@v0.2.2#subdirectory=envs/echo_env"

# %% [markdown]
# ## 1. Verify the Hosted Echo Environment
#
# First, let's confirm the hosted Echo environment works.

# %%
from echo_env import EchoEnv, CallToolAction

ECHO_URL = "https://mroyme-echo-env.hf.space"

with EchoEnv(base_url=ECHO_URL).sync() as env:
    result = env.reset()
    result = env.step(CallToolAction(tool_name="echo_with_length", arguments= {"message": "Hello, OpenEnv!"}))
    print(f"Sent: ping")
    print(f"Received: {result.observation}")
    print(f"This is the standard Echo — it returns exactly what you send.")
# Out:
# Sent: ping
# Received: done=False reward=None metadata={} tool_name='echo_with_length' result={'content': [{'type': 'text', 'text': '{"message":"Hello, OpenEnv!","length":15}', 'annotations': None, 'meta': None}], 'structured_content': {'message': 'Hello, OpenEnv!', 'length': 15}, 'meta': None, 'data': {'message': 'Hello, OpenEnv!', 'length': 15}, 'is_error': False} error=None
# This is the standard Echo — it returns exactly what you send.

# %% [markdown]
# ## 2. Clone the Echo Environment
#
# Clone the Space repository to get the full source code.

# %%
# !git clone https://huggingface.co/spaces/mroyme/echo_env echo-env-modified 2>/dev/null || echo "Already cloned"
# !git clone https://huggingface.co/spaces/mroyme/echo_env echo-env-modified || echo Already cloned
import os
os.listdir("echo-env-modified")
# Out:
# Cloning into 'echo-env-modified'...
# Updating files:  10% (23/230)
# Updating files:  11% (26/230)
# Updating files:  12% (28/230)
# Updating files:  13% (30/230)
# Updating files:  14% (33/230)
# Updating files:  15% (35/230)
# Updating files:  16% (37/230)
# Updating files:  17% (40/230)
# Updating files:  18% (42/230)
# Updating files:  19% (44/230)
# Updating files:  20% (46/230)
# Updating files:  21% (49/230)
# Updating files:  22% (51/230)
# Updating files:  23% (53/230)
# Updating files:  24% (56/230)
# Updating files:  25% (58/230)
# Updating files:  26% (60/230)
# Updating files:  27% (63/230)
# Updating files:  28% (65/230)
# Updating files:  29% (67/230)
# Updating files:  30% (69/230)
# Updating files:  31% (72/230)
# Updating files:  32% (74/230)
# Updating files:  33% (76/230)
# Updating files:  34% (79/230)
# Updating files:  35% (81/230)
# Updating files:  36% (83/230)
# Updating files:  37% (86/230)
# Updating files:  38% (88/230)
# Updating files:  39% (90/230)
# Updating files:  40% (92/230)
# Updating files:  41% (95/230)
# Updating files:  42% (97/230)
# Updating files:  43% (99/230)
# Updating files:  44% (102/230)
# Updating files:  45% (104/230)
# Updating files:  46% (106/230)
# Updating files:  47% (109/230)
# Updating files:  48% (111/230)
# Updating files:  49% (113/230)
# Updating files:  50% (115/230)
# Updating files:  51% (118/230)
# Updating files:  52% (120/230)
# Updating files:  53% (122/230)
# Updating files:  54% (125/230)
# Updating files:  55% (127/230)
# Updating files:  56% (129/230)
# Updating files:  57% (132/230)
# Updating files:  58% (134/230)
# Updating files:  59% (136/230)
# Updating files:  60% (138/230)
# Updating files:  61% (141/230)
# Updating files:  62% (143/230)
# Updating files:  63% (145/230)
# Updating files:  64% (148/230)
# Updating files:  65% (150/230)
# Updating files:  66% (152/230)
# Updating files:  67% (155/230)
# Updating files:  68% (157/230)
# Updating files:  69% (159/230)
# Updating files:  70% (161/230)
# Updating files:  71% (164/230)
# Updating files:  72% (166/230)
# Updating files:  73% (168/230)
# Updating files:  74% (171/230)
# Updating files:  75% (173/230)
# Updating files:  76% (175/230)
# Updating files:  77% (178/230)
# Updating files:  78% (180/230)
# Updating files:  79% (182/230)
# Updating files:  80% (184/230)
# Updating files:  81% (187/230)
# Updating files:  82% (189/230)
# Updating files:  83% (191/230)
# Updating files:  84% (194/230)
# Updating files:  85% (196/230)
# Updating files:  86% (198/230)
# Updating files:  87% (201/230)
# Updating files:  88% (203/230)
# Updating files:  89% (205/230)
# Updating files:  90% (207/230)
# Updating files:  91% (210/230)
# Updating files:  92% (212/230)
# Updating files:  93% (214/230)
# Updating files:  94% (217/230)
# Updating files:  95% (219/230)
# Updating files:  96% (221/230)
# Updating files:  97% (224/230)
# Updating files:  98% (226/230)
# Updating files:  99% (228/230)
# Updating files: 100% (230/230)
# Updating files: 100% (230/230), done.
# ['.git',
#  '.gitattributes',
#  'client.py',
#  'Dockerfile',
#  'envs',
#  'openenv.yaml',
#  'openenv_echo_env.egg-info',
#  'pyproject.toml',
#  'README.md',
#  'server',
#  'src',
#  'uv.toml',
#  'wheels',
#  '__init__.py']

# %% [markdown]
# ## 3. Explore the Structure
#
# Every OpenEnv environment follows the same layout.

# %%
# List all .py, .yaml, .toml, and Dockerfile files recursively (cross-platform)
#!find echo-env-modified -type f -name "*.py" -o -name "*.yaml" -o -name "*.toml" -o -name "Dockerfile" | sort
import pathlib
patterns = ["*.py", "*.yaml", "*.toml", "Dockerfile"]
base = pathlib.Path("echo-env-modified")
files = []
for pattern in patterns:
    files.extend(base.rglob(pattern))
for f in sorted(files):
    print(f)
# Out:
# echo-env-modified\__init__.py
# echo-env-modified\client.py
# echo-env-modified\Dockerfile
# echo-env-modified\envs\echo_env\__init__.py
# echo-env-modified\envs\echo_env\client.py
# echo-env-modified\envs\echo_env\openenv.yaml
# echo-env-modified\envs\echo_env\pyproject.toml
# echo-env-modified\envs\echo_env\server\__init__.py
# echo-env-modified\envs\echo_env\server\app.py
# echo-env-modified\envs\echo_env\server\Dockerfile
# echo-env-modified\envs\echo_env\server\echo_environment.py
# echo-env-modified\envs\echo_env\uv.toml
# echo-env-modified\openenv.yaml
# echo-env-modified\pyproject.toml
# echo-env-modified\server\__init__.py
# echo-env-modified\server\app.py
# echo-env-modified\server\Dockerfile
# echo-env-modified\server\echo_environment.py
# echo-env-modified\src\__init__.py
# echo-env-modified\src\core\__init__.py
# echo-env-modified\src\core\client_types.py
# echo-env-modified\src\core\containers\__init__.py
# echo-env-modified\src\core\containers\images\Dockerfile
# echo-env-modified\src\core\containers\runtime\__init__.py
# echo-env-modified\src\core\containers\runtime\daytona_provider.py
# echo-env-modified\src\core\containers\runtime\providers.py
# echo-env-modified\src\core\containers\runtime\uv_provider.py
# echo-env-modified\src\core\containers\test_local_docker_provider.py
# echo-env-modified\src\core\env_client.py
# echo-env-modified\src\core\env_server\__init__.py
# echo-env-modified\src\core\env_server\base_transforms.py
# echo-env-modified\src\core\env_server\exceptions.py
# echo-env-modified\src\core\env_server\gradio_theme.py
# echo-env-modified\src\core\env_server\gradio_ui.py
# echo-env-modified\src\core\env_server\http_server.py
# echo-env-modified\src\core\env_server\interfaces.py
# echo-env-modified\src\core\env_server\mcp_environment.py
# echo-env-modified\src\core\env_server\mcp_types.py
# echo-env-modified\src\core\env_server\route_config.py
# echo-env-modified\src\core\env_server\serialization.py
# echo-env-modified\src\core\env_server\types.py
# echo-env-modified\src\core\env_server\web_interface.py
# echo-env-modified\src\core\evals\__init__.py
# echo-env-modified\src\core\evals\base.py
# echo-env-modified\src\core\evals\inspect_harness.py
# echo-env-modified\src\core\evals\types.py
# echo-env-modified\src\core\generic_client.py
# echo-env-modified\src\core\llm_client.py
# echo-env-modified\src\core\mcp_client.py
# echo-env-modified\src\core\openenv\__init__.py
# echo-env-modified\src\core\openenv\auto\__init__.py
# echo-env-modified\src\core\openenv\auto\_discovery.py
# echo-env-modified\src\core\openenv\auto\auto_action.py
# echo-env-modified\src\core\openenv\auto\auto_env.py
# echo-env-modified\src\core\openenv\cli\__init__.py
# echo-env-modified\src\core\openenv\cli\__main__.py
# echo-env-modified\src\core\openenv\cli\_cli_utils.py
# echo-env-modified\src\core\openenv\cli\_validation.py
# echo-env-modified\src\core\openenv\cli\commands\__init__.py
# echo-env-modified\src\core\openenv\cli\commands\build.py
# echo-env-modified\src\core\openenv\cli\commands\fork.py
# echo-env-modified\src\core\openenv\cli\commands\init.py
# echo-env-modified\src\core\openenv\cli\commands\push.py
# echo-env-modified\src\core\openenv\cli\commands\serve.py
# echo-env-modified\src\core\openenv\cli\commands\skills.py
# echo-env-modified\src\core\openenv\cli\commands\validate.py
# echo-env-modified\src\core\openenv\cli\templates\__init__.py
# echo-env-modified\src\core\openenv\cli\templates\openenv_env\__init__.py
# echo-env-modified\src\core\openenv\cli\templates\openenv_env\client.py
# echo-env-modified\src\core\openenv\cli\templates\openenv_env\models.py
# echo-env-modified\src\core\openenv\cli\templates\openenv_env\openenv.yaml
# echo-env-modified\src\core\openenv\cli\templates\openenv_env\pyproject.toml
# echo-env-modified\src\core\openenv\cli\templates\openenv_env\server\__ENV_NAME___environment.py
# echo-env-modified\src\core\openenv\cli\templates\openenv_env\server\__init__.py
# echo-env-modified\src\core\openenv\cli\templates\openenv_env\server\app.py
# echo-env-modified\src\core\openenv\cli\templates\openenv_env\server\Dockerfile
# echo-env-modified\src\core\openenv\core\__init__.py
# echo-env-modified\src\core\openenv\core\client_types.py
# echo-env-modified\src\core\openenv\core\containers\__init__.py
# echo-env-modified\src\core\openenv\core\containers\images\Dockerfile
# echo-env-modified\src\core\openenv\core\containers\runtime\__init__.py
# echo-env-modified\src\core\openenv\core\containers\runtime\daytona_provider.py
# echo-env-modified\src\core\openenv\core\containers\runtime\providers.py
# echo-env-modified\src\core\openenv\core\containers\runtime\uv_provider.py
# echo-env-modified\src\core\openenv\core\containers\test_local_docker_provider.py
# echo-env-modified\src\core\openenv\core\env_client.py
# echo-env-modified\src\core\openenv\core\env_server\__init__.py
# echo-env-modified\src\core\openenv\core\env_server\base_transforms.py
# echo-env-modified\src\core\openenv\core\env_server\exceptions.py
# echo-env-modified\src\core\openenv\core\env_server\gradio_theme.py
# echo-env-modified\src\core\openenv\core\env_server\gradio_ui.py
# echo-env-modified\src\core\openenv\core\env_server\http_server.py
# echo-env-modified\src\core\openenv\core\env_server\interfaces.py
# echo-env-modified\src\core\openenv\core\env_server\mcp_environment.py
# echo-env-modified\src\core\openenv\core\env_server\mcp_types.py
# echo-env-modified\src\core\openenv\core\env_server\route_config.py
# echo-env-modified\src\core\openenv\core\env_server\serialization.py
# echo-env-modified\src\core\openenv\core\env_server\types.py
# echo-env-modified\src\core\openenv\core\env_server\web_interface.py
# echo-env-modified\src\core\openenv\core\evals\__init__.py
# echo-env-modified\src\core\openenv\core\evals\base.py
# echo-env-modified\src\core\openenv\core\evals\inspect_harness.py
# echo-env-modified\src\core\openenv\core\evals\types.py
# echo-env-modified\src\core\openenv\core\generic_client.py
# echo-env-modified\src\core\openenv\core\llm_client.py
# echo-env-modified\src\core\openenv\core\mcp_client.py
# echo-env-modified\src\core\openenv\core\rubrics\__init__.py
# echo-env-modified\src\core\openenv\core\rubrics\base.py
# echo-env-modified\src\core\openenv\core\rubrics\containers.py
# echo-env-modified\src\core\openenv\core\rubrics\llm_judge.py
# echo-env-modified\src\core\openenv\core\rubrics\trajectory.py
# echo-env-modified\src\core\openenv\core\sync_client.py
# echo-env-modified\src\core\openenv\core\tools\__init__.py
# echo-env-modified\src\core\openenv\core\tools\git_server_client.py
# echo-env-modified\src\core\openenv\core\tools\local_python_executor.py
# echo-env-modified\src\core\openenv\core\utils.py
# echo-env-modified\src\core\rubrics\__init__.py
# echo-env-modified\src\core\rubrics\base.py
# echo-env-modified\src\core\rubrics\containers.py
# echo-env-modified\src\core\rubrics\llm_judge.py
# echo-env-modified\src\core\rubrics\trajectory.py
# echo-env-modified\src\core\sync_client.py
# echo-env-modified\src\core\tools\__init__.py
# echo-env-modified\src\core\tools\git_server_client.py
# echo-env-modified\src\core\tools\local_python_executor.py
# echo-env-modified\src\core\utils.py
# echo-env-modified\src\openenv\__init__.py
# echo-env-modified\src\openenv\auto\__init__.py
# echo-env-modified\src\openenv\auto\_discovery.py
# echo-env-modified\src\openenv\auto\auto_action.py
# echo-env-modified\src\openenv\auto\auto_env.py
# echo-env-modified\src\openenv\cli\__init__.py
# echo-env-modified\src\openenv\cli\__main__.py
# echo-env-modified\src\openenv\cli\_cli_utils.py
# echo-env-modified\src\openenv\cli\_validation.py
# echo-env-modified\src\openenv\cli\commands\__init__.py
# echo-env-modified\src\openenv\cli\commands\build.py
# echo-env-modified\src\openenv\cli\commands\fork.py
# echo-env-modified\src\openenv\cli\commands\init.py
# echo-env-modified\src\openenv\cli\commands\push.py
# echo-env-modified\src\openenv\cli\commands\serve.py
# echo-env-modified\src\openenv\cli\commands\skills.py
# echo-env-modified\src\openenv\cli\commands\validate.py
# echo-env-modified\src\openenv\cli\templates\__init__.py
# echo-env-modified\src\openenv\cli\templates\openenv_env\__init__.py
# echo-env-modified\src\openenv\cli\templates\openenv_env\client.py
# echo-env-modified\src\openenv\cli\templates\openenv_env\models.py
# echo-env-modified\src\openenv\cli\templates\openenv_env\openenv.yaml
# echo-env-modified\src\openenv\cli\templates\openenv_env\pyproject.toml
# echo-env-modified\src\openenv\cli\templates\openenv_env\server\__ENV_NAME___environment.py
# echo-env-modified\src\openenv\cli\templates\openenv_env\server\__init__.py
# echo-env-modified\src\openenv\cli\templates\openenv_env\server\app.py
# echo-env-modified\src\openenv\cli\templates\openenv_env\server\Dockerfile
# echo-env-modified\src\openenv\core\__init__.py
# echo-env-modified\src\openenv\core\client_types.py
# echo-env-modified\src\openenv\core\containers\__init__.py
# echo-env-modified\src\openenv\core\containers\images\Dockerfile
# echo-env-modified\src\openenv\core\containers\runtime\__init__.py
# echo-env-modified\src\openenv\core\containers\runtime\daytona_provider.py
# echo-env-modified\src\openenv\core\containers\runtime\providers.py
# echo-env-modified\src\openenv\core\containers\runtime\uv_provider.py
# echo-env-modified\src\openenv\core\containers\test_local_docker_provider.py
# echo-env-modified\src\openenv\core\env_client.py
# echo-env-modified\src\openenv\core\env_server\__init__.py
# echo-env-modified\src\openenv\core\env_server\base_transforms.py
# echo-env-modified\src\openenv\core\env_server\exceptions.py
# echo-env-modified\src\openenv\core\env_server\gradio_theme.py
# echo-env-modified\src\openenv\core\env_server\gradio_ui.py
# echo-env-modified\src\openenv\core\env_server\http_server.py
# echo-env-modified\src\openenv\core\env_server\interfaces.py
# echo-env-modified\src\openenv\core\env_server\mcp_environment.py
# echo-env-modified\src\openenv\core\env_server\mcp_types.py
# echo-env-modified\src\openenv\core\env_server\route_config.py
# echo-env-modified\src\openenv\core\env_server\serialization.py
# echo-env-modified\src\openenv\core\env_server\types.py
# echo-env-modified\src\openenv\core\env_server\web_interface.py
# echo-env-modified\src\openenv\core\evals\__init__.py
# echo-env-modified\src\openenv\core\evals\base.py
# echo-env-modified\src\openenv\core\evals\inspect_harness.py
# echo-env-modified\src\openenv\core\evals\types.py
# echo-env-modified\src\openenv\core\generic_client.py
# echo-env-modified\src\openenv\core\llm_client.py
# echo-env-modified\src\openenv\core\mcp_client.py
# echo-env-modified\src\openenv\core\rubrics\__init__.py
# echo-env-modified\src\openenv\core\rubrics\base.py
# echo-env-modified\src\openenv\core\rubrics\containers.py
# echo-env-modified\src\openenv\core\rubrics\llm_judge.py
# echo-env-modified\src\openenv\core\rubrics\trajectory.py
# echo-env-modified\src\openenv\core\sync_client.py
# echo-env-modified\src\openenv\core\tools\__init__.py
# echo-env-modified\src\openenv\core\tools\git_server_client.py
# echo-env-modified\src\openenv\core\tools\local_python_executor.py
# echo-env-modified\src\openenv\core\utils.py
# echo-env-modified\src\openenv_core\__init__.py
# echo-env-modified\uv.toml

# %%
# Look at the environment logic (cross-platform)
env_file = "echo-env-modified/envs/echo_env/server/echo_environment.py"
with open(env_file, "r", encoding="utf-8") as f:
    print(f.read())
# Out:
# # Copyright (c) Meta Platforms, Inc. and affiliates.
# # All rights reserved.
# #
# # This source code is licensed under the BSD-style license found in the
# # LICENSE file in the root directory of this source tree.
#
# """
# Echo Environment Implementation.
#
# A pure MCP environment that echoes back messages sent to it.
# This demonstrates how to build an MCPEnvironment with inline FastMCP tools.
#
# All interactions happen through MCP tools:
# - `echo_message(message)`: Echo back the provided message
# - `echo_with_length(message)`: Echo back the message with its length
#
# Example:
#     >>> from openenv.core.env_server.mcp_types import ListToolsAction, CallToolAction
#     >>> env = EchoEnvironment()
#     >>> env.reset()
#     >>>
#     >>> # List available tools
#     >>> obs = env.step(ListToolsAction())
#     >>> print([t.name for t in obs.tools])  # ["echo_message", "echo_with_length"]
#     >>>
#     >>> # Call a tool
#     >>> obs = env.step(CallToolAction(tool_name="echo_message", arguments={"message": "Hi!"}))
#     >>> print(obs.result)  # "Hi!"
# """
#
# from typing import Any, Optional
# from uuid import uuid4
#
# # Support both in-repo and standalone imports
# try:
#     # In-repo imports (when running from OpenEnv repository)
#     from openenv.core.env_server.mcp_environment import MCPEnvironment
#     from openenv.core.env_server.types import Action, Observation, State
# except ImportError:
#     # Standalone imports (when environment is standalone with openenv from pip)
#     from openenv.core.env_server.mcp_environment import MCPEnvironment
#     from openenv.core.env_server.types import Action, Observation, State
#
# from fastmcp import FastMCP
#
#
# class EchoEnvironment(MCPEnvironment):
#     """
#     A pure MCP echo environment that echoes back messages.
#
#     This environment exposes all functionality through MCP tools:
#     - `echo_message`: Echo back the provided message
#     - `echo_with_length`: Echo back the message with its length
#
#     The environment inherits MCP support (ListToolsAction, CallToolAction)
#     from the MCPEnvironment base class. No legacy action types are supported.
#
#     Example using MCPToolClient:
#         >>> from openenv.core.mcp_client import MCPToolClient
#         >>>
#         >>> with MCPToolClient(base_url="http://localhost:8000") as env:
#         ...     env.reset()
#         ...     tools = env.list_tools()
#         ...     print([t.name for t in tools])
#         ...     result = env.call_tool("echo_message", message="Hello!")
#         ...     print(result)
#     """
#
#     def __init__(self):
#         """Initialize the echo environment with MCP server and tools."""
#         # Create MCP server and define tools inline
#         mcp = FastMCP("echo_env")
#
#         @mcp.tool
#         def echo_message(message: str) -> str:
#             """
#             Echo back the provided message.
#
#             Args:
#                 message: The message to echo back
#
#             Returns:
#                 The same message that was provided
#             """
#             return message
#
#         @mcp.tool
#         def echo_with_length(message: str) -> dict:
#             """
#             Echo back the message with its length.
#
#             Args:
#                 message: The message to echo back
#
#             Returns:
#                 Dictionary with the message and its length
#             """
#             return {"message": message, "length": len(message)}
#
#         # Pass the MCP server to the base class
#         super().__init__(mcp)
#         self._state = State(episode_id=str(uuid4()), step_count=0)
#         self._reset_count = 0
#
#     def reset(
#         self,
#         seed: Optional[int] = None,
#         episode_id: Optional[str] = None,
#         **kwargs: Any,
#     ) -> Observation:
#         """
#         Reset the environment.
#
#         Args:
#             seed: Optional random seed (unused in echo env)
#             episode_id: Optional episode ID to use
#             **kwargs: Additional reset options
#
#         Returns:
#             Observation indicating the environment is ready
#         """
#         self._state = State(
#             episode_id=episode_id or str(uuid4()),
#             step_count=0,
#         )
#         self._reset_count += 1
#
#         return Observation(
#             done=False,
#             reward=0.0,
#             metadata={"status": "ready", "message": "Echo environment ready!"},
#         )
#
#     def _step_impl(
#         self,
#         action: Action,
#         timeout_s: Optional[float] = None,
#         **kwargs: Any,
#     ) -> Observation:
#         """
#         Handle non-MCP actions.
#
#         This environment only supports MCP actions (ListToolsAction, CallToolAction).
#         Any other action type returns an error observation.
#
#         Args:
#             action: The action to execute
#             timeout_s: Optional timeout (unused)
#             **kwargs: Additional arguments
#
#         Returns:
#             Observation with error for unknown action types
#         """
#         return Observation(
#             done=False,
#             reward=0.0,
#             metadata={
#                 "error": f"Unknown action type: {type(action).__name__}. "
#                 "Use ListToolsAction or CallToolAction for MCP interactions."
#             },
#         )
#
#     def step(
#         self,
#         action: Action,
#         timeout_s: Optional[float] = None,
#         **kwargs: Any,
#     ) -> Observation:
#         """
#         Execute a step in the environment.
#
#         Delegates to base class for MCP actions. Increments step count for all actions.
#
#         Args:
#             action: The MCP action to execute (ListToolsAction or CallToolAction)
#             timeout_s: Optional timeout for the action
#             **kwargs: Additional arguments
#
#         Returns:
#             Observation from the action execution
#         """
#         # Increment step count for all actions
#         self._state.step_count += 1
#
#         # Let the base class handle MCP actions and non-MCP routing
#         return super().step(action, timeout_s=timeout_s, **kwargs)
#
#     async def step_async(
#         self,
#         action: Action,
#         timeout_s: Optional[float] = None,
#         **kwargs: Any,
#     ) -> Observation:
#         """
#         Async step used by the WebSocket handler.
#
#         Increments step count then delegates to MCPEnvironment.step_async,
#         which routes MCP actions without going through run_async_safely.
#         """
#         self._state.step_count += 1
#         return await super().step_async(action, timeout_s=timeout_s, **kwargs)
#
#     @property
#     def state(self) -> State:
#         """
#         Get the current environment state.
#
#         Returns:
#             Current State with episode_id and step_count
#         """
#         return self._state

# %% [markdown]
# ## 4. Modify the Environment
#
# Let's make a "Reverse Echo" — instead of echoing back the message, it reverses it.
#
# We'll modify the `step()` method in `environment.py`.

# %%
# Read the current environment.py
env_file = "echo-env-modified/envs/echo_env/server/echo_environment.py"

with open(env_file, "r") as f:
    content = f.read()

print("Original environment.py:")
print(content)
# Out:
# Original environment.py:
# # Copyright (c) Meta Platforms, Inc. and affiliates.
# # All rights reserved.
# #
# # This source code is licensed under the BSD-style license found in the
# # LICENSE file in the root directory of this source tree.
#
# """
# Echo Environment Implementation.
#
# A pure MCP environment that echoes back messages sent to it.
# This demonstrates how to build an MCPEnvironment with inline FastMCP tools.
#
# All interactions happen through MCP tools:
# - `echo_message(message)`: Echo back the provided message
# - `echo_with_length(message)`: Echo back the message with its length
#
# Example:
#     >>> from openenv.core.env_server.mcp_types import ListToolsAction, CallToolAction
#     >>> env = EchoEnvironment()
#     >>> env.reset()
#     >>>
#     >>> # List available tools
#     >>> obs = env.step(ListToolsAction())
#     >>> print([t.name for t in obs.tools])  # ["echo_message", "echo_with_length"]
#     >>>
#     >>> # Call a tool
#     >>> obs = env.step(CallToolAction(tool_name="echo_message", arguments={"message": "Hi!"}))
#     >>> print(obs.result)  # "Hi!"
# """
#
# from typing import Any, Optional
# from uuid import uuid4
#
# # Support both in-repo and standalone imports
# try:
#     # In-repo imports (when running from OpenEnv repository)
#     from openenv.core.env_server.mcp_environment import MCPEnvironment
#     from openenv.core.env_server.types import Action, Observation, State
# except ImportError:
#     # Standalone imports (when environment is standalone with openenv from pip)
#     from openenv.core.env_server.mcp_environment import MCPEnvironment
#     from openenv.core.env_server.types import Action, Observation, State
#
# from fastmcp import FastMCP
#
#
# class EchoEnvironment(MCPEnvironment):
#     """
#     A pure MCP echo environment that echoes back messages.
#
#     This environment exposes all functionality through MCP tools:
#     - `echo_message`: Echo back the provided message
#     - `echo_with_length`: Echo back the message with its length
#
#     The environment inherits MCP support (ListToolsAction, CallToolAction)
#     from the MCPEnvironment base class. No legacy action types are supported.
#
#     Example using MCPToolClient:
#         >>> from openenv.core.mcp_client import MCPToolClient
#         >>>
#         >>> with MCPToolClient(base_url="http://localhost:8000") as env:
#         ...     env.reset()
#         ...     tools = env.list_tools()
#         ...     print([t.name for t in tools])
#         ...     result = env.call_tool("echo_message", message="Hello!")
#         ...     print(result)
#     """
#
#     def __init__(self):
#         """Initialize the echo environment with MCP server and tools."""
#         # Create MCP server and define tools inline
#         mcp = FastMCP("echo_env")
#
#         @mcp.tool
#         def echo_message(message: str) -> str:
#             """
#             Echo back the provided message.
#
#             Args:
#                 message: The message to echo back
#
#             Returns:
#                 The same message that was provided
#             """
#             return message
#
#         @mcp.tool
#         def echo_with_length(message: str) -> dict:
#             """
#             Echo back the message with its length.
#
#             Args:
#                 message: The message to echo back
#
#             Returns:
#                 Dictionary with the message and its length
#             """
#             return {"message": message, "length": len(message)}
#
#         # Pass the MCP server to the base class
#         super().__init__(mcp)
#         self._state = State(episode_id=str(uuid4()), step_count=0)
#         self._reset_count = 0
#
#     def reset(
#         self,
#         seed: Optional[int] = None,
#         episode_id: Optional[str] = None,
#         **kwargs: Any,
#     ) -> Observation:
#         """
#         Reset the environment.
#
#         Args:
#             seed: Optional random seed (unused in echo env)
#             episode_id: Optional episode ID to use
#             **kwargs: Additional reset options
#
#         Returns:
#             Observation indicating the environment is ready
#         """
#         self._state = State(
#             episode_id=episode_id or str(uuid4()),
#             step_count=0,
#         )
#         self._reset_count += 1
#
#         return Observation(
#             done=False,
#             reward=0.0,
#             metadata={"status": "ready", "message": "Echo environment ready!"},
#         )
#
#     def _step_impl(
#         self,
#         action: Action,
#         timeout_s: Optional[float] = None,
#         **kwargs: Any,
#     ) -> Observation:
#         """
#         Handle non-MCP actions.
#
#         This environment only supports MCP actions (ListToolsAction, CallToolAction).
#         Any other action type returns an error observation.
#
#         Args:
#             action: The action to execute
#             timeout_s: Optional timeout (unused)
#             **kwargs: Additional arguments
#
#         Returns:
#             Observation with error for unknown action types
#         """
#         return Observation(
#             done=False,
#             reward=0.0,
#             metadata={
#                 "error": f"Unknown action type: {type(action).__name__}. "
#                 "Use ListToolsAction or CallToolAction for MCP interactions."
#             },
#         )
#
#     def step(
#         self,
#         action: Action,
#         timeout_s: Optional[float] = None,
#         **kwargs: Any,
#     ) -> Observation:
#         """
#         Execute a step in the environment.
#
#         Delegates to base class for MCP actions. Increments step count for all actions.
#
#         Args:
#             action: The MCP action to execute (ListToolsAction or CallToolAction)
#             timeout_s: Optional timeout for the action
#             **kwargs: Additional arguments
#
#         Returns:
#             Observation from the action execution
#         """
#         # Increment step count for all actions
#         self._state.step_count += 1
#
#         # Let the base class handle MCP actions and non-MCP routing
#         return super().step(action, timeout_s=timeout_s, **kwargs)
#
#     async def step_async(
#         self,
#         action: Action,
#         timeout_s: Optional[float] = None,
#         **kwargs: Any,
#     ) -> Observation:
#         """
#         Async step used by the WebSocket handler.
#
#         Increments step count then delegates to MCPEnvironment.step_async,
#         which routes MCP actions without going through run_async_safely.
#         """
#         self._state.step_count += 1
#         return await super().step_async(action, timeout_s=timeout_s, **kwargs)
#
#     @property
#     def state(self) -> State:
#         """
#         Get the current environment state.
#
#         Returns:
#             Current State with episode_id and step_count
#         """
#         return self._state

# %%
# Modify: reverse the echo message in the step method
# This is a simple find-and-replace — adapt based on the actual file content

modified = content.replace(
    'return message',
    'return message[::-1]',
    1  # Replace only the first occurrence (in echo_message tool)
)

with open(env_file, "w") as f:
    f.write(modified)

print("Modified environment.py (step now reverses the message):")
print(modified)
# Out:
# Modified environment.py (step now reverses the message):
# # Copyright (c) Meta Platforms, Inc. and affiliates.
# # All rights reserved.
# #
# # This source code is licensed under the BSD-style license found in the
# # LICENSE file in the root directory of this source tree.
#
# """
# Echo Environment Implementation.
#
# A pure MCP environment that echoes back messages sent to it.
# This demonstrates how to build an MCPEnvironment with inline FastMCP tools.
#
# All interactions happen through MCP tools:
# - `echo_message(message)`: Echo back the provided message
# - `echo_with_length(message)`: Echo back the message with its length
#
# Example:
#     >>> from openenv.core.env_server.mcp_types import ListToolsAction, CallToolAction
#     >>> env = EchoEnvironment()
#     >>> env.reset()
#     >>>
#     >>> # List available tools
#     >>> obs = env.step(ListToolsAction())
#     >>> print([t.name for t in obs.tools])  # ["echo_message", "echo_with_length"]
#     >>>
#     >>> # Call a tool
#     >>> obs = env.step(CallToolAction(tool_name="echo_message", arguments={"message": "Hi!"}))
#     >>> print(obs.result)  # "Hi!"
# """
#
# from typing import Any, Optional
# from uuid import uuid4
#
# # Support both in-repo and standalone imports
# try:
#     # In-repo imports (when running from OpenEnv repository)
#     from openenv.core.env_server.mcp_environment import MCPEnvironment
#     from openenv.core.env_server.types import Action, Observation, State
# except ImportError:
#     # Standalone imports (when environment is standalone with openenv from pip)
#     from openenv.core.env_server.mcp_environment import MCPEnvironment
#     from openenv.core.env_server.types import Action, Observation, State
#
# from fastmcp import FastMCP
#
#
# class EchoEnvironment(MCPEnvironment):
#     """
#     A pure MCP echo environment that echoes back messages.
#
#     This environment exposes all functionality through MCP tools:
#     - `echo_message`: Echo back the provided message
#     - `echo_with_length`: Echo back the message with its length
#
#     The environment inherits MCP support (ListToolsAction, CallToolAction)
#     from the MCPEnvironment base class. No legacy action types are supported.
#
#     Example using MCPToolClient:
#         >>> from openenv.core.mcp_client import MCPToolClient
#         >>>
#         >>> with MCPToolClient(base_url="http://localhost:8000") as env:
#         ...     env.reset()
#         ...     tools = env.list_tools()
#         ...     print([t.name for t in tools])
#         ...     result = env.call_tool("echo_message", message="Hello!")
#         ...     print(result)
#     """
#
#     def __init__(self):
#         """Initialize the echo environment with MCP server and tools."""
#         # Create MCP server and define tools inline
#         mcp = FastMCP("echo_env")
#
#         @mcp.tool
#         def echo_message(message: str) -> str:
#             """
#             Echo back the provided message.
#
#             Args:
#                 message: The message to echo back
#
#             Returns:
#                 The same message that was provided
#             """
#             return message[::-1]
#
#         @mcp.tool
#         def echo_with_length(message: str) -> dict:
#             """
#             Echo back the message with its length.
#
#             Args:
#                 message: The message to echo back
#
#             Returns:
#                 Dictionary with the message and its length
#             """
#             return {"message": message, "length": len(message)}
#
#         # Pass the MCP server to the base class
#         super().__init__(mcp)
#         self._state = State(episode_id=str(uuid4()), step_count=0)
#         self._reset_count = 0
#
#     def reset(
#         self,
#         seed: Optional[int] = None,
#         episode_id: Optional[str] = None,
#         **kwargs: Any,
#     ) -> Observation:
#         """
#         Reset the environment.
#
#         Args:
#             seed: Optional random seed (unused in echo env)
#             episode_id: Optional episode ID to use
#             **kwargs: Additional reset options
#
#         Returns:
#             Observation indicating the environment is ready
#         """
#         self._state = State(
#             episode_id=episode_id or str(uuid4()),
#             step_count=0,
#         )
#         self._reset_count += 1
#
#         return Observation(
#             done=False,
#             reward=0.0,
#             metadata={"status": "ready", "message": "Echo environment ready!"},
#         )
#
#     def _step_impl(
#         self,
#         action: Action,
#         timeout_s: Optional[float] = None,
#         **kwargs: Any,
#     ) -> Observation:
#         """
#         Handle non-MCP actions.
#
#         This environment only supports MCP actions (ListToolsAction, CallToolAction).
#         Any other action type returns an error observation.
#
#         Args:
#             action: The action to execute
#             timeout_s: Optional timeout (unused)
#             **kwargs: Additional arguments
#
#         Returns:
#             Observation with error for unknown action types
#         """
#         return Observation(
#             done=False,
#             reward=0.0,
#             metadata={
#                 "error": f"Unknown action type: {type(action).__name__}. "
#                 "Use ListToolsAction or CallToolAction for MCP interactions."
#             },
#         )
#
#     def step(
#         self,
#         action: Action,
#         timeout_s: Optional[float] = None,
#         **kwargs: Any,
#     ) -> Observation:
#         """
#         Execute a step in the environment.
#
#         Delegates to base class for MCP actions. Increments step count for all actions.
#
#         Args:
#             action: The MCP action to execute (ListToolsAction or CallToolAction)
#             timeout_s: Optional timeout for the action
#             **kwargs: Additional arguments
#
#         Returns:
#             Observation from the action execution
#         """
#         # Increment step count for all actions
#         self._state.step_count += 1
#
#         # Let the base class handle MCP actions and non-MCP routing
#         return super().step(action, timeout_s=timeout_s, **kwargs)
#
#     async def step_async(
#         self,
#         action: Action,
#         timeout_s: Optional[float] = None,
#         **kwargs: Any,
#     ) -> Observation:
#         """
#         Async step used by the WebSocket handler.
#
#         Increments step count then delegates to MCPEnvironment.step_async,
#         which routes MCP actions without going through run_async_safely.
#         """
#         self._state.step_count += 1
#         return await super().step_async(action, timeout_s=timeout_s, **kwargs)
#
#     @property
#     def state(self) -> State:
#         """
#         Get the current environment state.
#
#         Returns:
#             Current State with episode_id and step_count
#         """
#         return self._state

# %% [markdown]
# ## 5. Test Locally
#
# Start the modified server and connect to it.
#
# > In Colab, we'll start the server as a background process. Locally, you'd run `uv run server` in a separate terminal.

# %%
import subprocess
import time
import sys

# Start the server in the background
server = subprocess.Popen(
    [sys.executable, "-m", "uvicorn", "echo_env.server.app:app",
     "--host", "0.0.0.0", "--port", "8000"],
    cwd="echo-env-modified",
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE,
)

# Give it time to start
time.sleep(3)
print(f"Server started (PID: {server.pid})")
# Out:
# Server started (PID: 45244)

# %%
# Test the modified environment
with EchoEnv(base_url="http://localhost:8000").sync() as env:
    result = env.reset()

    test_messages = ["Hello", "OpenEnv", "Reverse this!"]
    for msg in test_messages:
        result = env.step(CallToolAction(tool_name="echo_with_length", arguments= {"message": msg}))
        print(f"Sent: {msg:20s} → Received: {result.observation}")
# Out:
# Sent: Hello                → Received: done=False reward=None metadata={} tool_name='echo_with_length' result=None error=ToolError(error_type=<ToolErrorType.TIMEOUT: 'timeout'>, message="Tool 'echo_with_length' timed out after 30.0 seconds")
# Sent: OpenEnv              → Received: done=False reward=None metadata={} tool_name='echo_with_length' result=None error=ToolError(error_type=<ToolErrorType.TIMEOUT: 'timeout'>, message="Tool 'echo_with_length' timed out after 30.0 seconds")
# Sent: Reverse this!        → Received: done=False reward=None metadata={} tool_name='echo_with_length' result=None error=ToolError(error_type=<ToolErrorType.TIMEOUT: 'timeout'>, message="Tool 'echo_with_length' timed out after 30.0 seconds")

# %%
# Clean up the server
server.terminate()
server.wait()
print("Server stopped.")
# Out:
# Server stopped.

# %% [markdown]
# ## 6. Deploy to HF Spaces
#
# Once your environment works locally, deploy it with `openenv push`.
#
# ```bash
# cd echo-env-modified
# openenv push --repo-id YOUR_USERNAME/reverse-echo-env
# ```
#
# Your environment is now live at:
# - **API:** `https://YOUR_USERNAME-reverse-echo-env.hf.space`
# - **Web UI:** `https://YOUR_USERNAME-reverse-echo-env.hf.space/web`
# - **Docs:** `https://YOUR_USERNAME-reverse-echo-env.hf.space/docs`

# %%
# Uncomment and run to deploy (requires HF token)
# !cd echo-env-modified && openenv push --repo-id YOUR_USERNAME/reverse-echo-env

# %% [markdown]
# ## 7. Connect to Your Deployed Environment
#
# After deployment, install the client and connect:

# %%
# Uncomment after deploying
# !pip install -q git+https://huggingface.co/spaces/YOUR_USERNAME/reverse-echo-env
#
# with EchoEnv(base_url="https://YOUR_USERNAME-reverse-echo-env.hf.space").sync() as env:
#     result = env.reset()
#     result = env.step(EchoAction(message="Deployed!"))
#     print(f"Response from your Space: {result.observation}")

# %% [markdown]
# ## 8. Docker Deployment (Alternative)
#
# You can also pull and run the Docker image locally:
#
# ```bash
# # Pull from HF registry (after deploying)
# docker pull registry.hf.space/YOUR_USERNAME-reverse-echo-env:latest
# docker run -d -p 8001:8000 registry.hf.space/YOUR_USERNAME-reverse-echo-env:latest
#
# # Or build from source
# cd echo-env-modified
# docker build -t reverse-echo:latest -f server/Dockerfile .
# docker run -d -p 8001:8000 reverse-echo:latest
# ```
#
# Connect the same way:
# ```python
# with EchoEnv(base_url="http://localhost:8001").sync() as env:
#     result = env.reset()
# ```

# %% [markdown]
# ## Summary
#
# What you did:
# 1. Cloned an existing environment from HF Spaces
# 2. Explored its structure (models, client, server)
# 3. Modified the environment logic (echo → reverse echo)
# 4. Tested locally with uvicorn
# 5. Deployed to HF Spaces with `openenv push`
#
# The workflow is always: **clone → modify → test → deploy**.
#
# **Next:** [Module 4](../module-4/README.md) — Building an environment from scratch.
